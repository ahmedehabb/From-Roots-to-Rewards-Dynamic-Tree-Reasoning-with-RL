# %%
# Import jsonl file and print the data
import json

dev_data = []

with open('../../released_data/2wikimultihopqa__v2_dev_random_100.jsonl') as f:
    for line in f:
        data = json.loads(line)
        dev_data.append({'question': data['question_text'], 'answer': data['answers_objects'][0]['spans'][0]})
        

with open('../../released_data/2wikimultihopqa__v2_dev_random_100.jsonl') as f:
    for line in f:
        data = json.loads(line)
        dev_data.append({'question': data['question_text'], 'answer': data['answers_objects'][0]['spans'][0]})
        
with open('../../released_data/musique_ans__v2_dev_random_100.jsonl') as f:
    for line in f:
        data = json.loads(line)
        dev_data.append({'question': data['question_text'], 'answer': data['answers_objects'][0]['spans'][0]})

# %%
len(dev_data)
# Out:
# 300

# %%
dev_data
# Out:
# [{'question': 'Who is the founder of the company which published Big Picture (Magazine)?',
#   'answer': 'Henry Wellcome'},
#  {'question': 'Are Antoine Jean-Baptiste Thomas and Canardo (Rapper) of the same nationality?',
#   'answer': 'yes'},
#  {'question': "Where did Temüge's father die?", 'answer': 'Khamag Mongol'},
#  {'question': "Who is Elizabeth Stuart, Countess Of Lennox's mother-in-law?",
#   'answer': 'Margaret Douglas'},
#  {'question': "When was Ludwig Gruno Of Hesse-Homburg's father born?",
#   'answer': '19 May 1673'},
#  {'question': 'Which song was released more recently, Come With Me (Pure Imagination) or Hold On Me (Grinspoon Song)?',
#   'answer': 'Come With Me (Pure Imagination)'},
#  {'question': 'Who was born first, Heo Keon or Ljiljana Nanušević?',
#   'answer': 'Ljiljana Nanušević'},
#  {'question': 'Which film was released more recently, The Black Duke or Avalalpam Vaikippoyi?',
#   'answer': 'Avalalpam Vaikippoyi'},
# ...
